# %%
# %run im2spain_starter.py
# Out:
# Predicting GPS from CLIP image features
#
# Loading Data
# Train Data Count: 27616
# 3 Nearest Neighbors:
# 31870484468.jpg
#    Coordinates: [37.380424 -5.994328]
# 4554482343.jpg
#    Coordinates: [40.036533 -3.609201]
# 53643099910.jpg
#    Coordinates: [37.38637  -5.992387]
# Constant Baseline Mean Displacement Error (miles): 3.65
# Running grid search for k (is_weighted=False)
# 1-NN mean displacement error (miles): 145.0
# 2-NN mean displacement error (miles): 140.0
# 3-NN mean displacement error (miles): 139.2
# 4-NN mean displacement error (miles): 140.0
# 5-NN mean displacement error (miles): 139.5
# 6-NN mean displacement error (miles): 141.7
# 7-NN mean displacement error (miles): 143.1
# 8-NN mean displacement error (miles): 143.5
# 9-NN mean displacement error (miles): 144.0
# 10-NN mean displacement error (miles): 145.3
# 20-NN mean displacement error (miles): 152.8
# 30-NN mean displacement error (miles): 157.5
# 40-NN mean displacement error (miles): 160.5
# ...
